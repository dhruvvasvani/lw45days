# %%
import pandas as pd

# %%
df = pd.read_csv("walmart.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
 df.shape
# Out:
# (6435, 8)

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
 df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("walmart.csv")
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
plt.figure(figsize=(8, 5))

plt.hist(df["Weekly_Sales"],bins=100)

plt.xlabel("Weekly Sales")
plt.ylabel("Frequency")
plt.show()

# %%
mean_store_sales = df.groupby("Store")["Weekly_Sales"].mean()

# %%
mean_store_sales.plot(kind="bar" , figsize=(10,5))
plt.title("Average Weekly sames By store")
plt.show()

# %%
plt.figure(figsize=(6, 4))

sns.boxplot(
    data=df,
    x="Holiday_Flag",
    y="Weekly_Sales"
)

plt.show()

# %%
plt.figure(figsize=(6, 4))

sns.scatterplot(
    data=df,
    x="Fuel_Price",
    y="Weekly_Sales",
)

plt.show()

# %%
plt.figure(figsize=(6, 4))

sns.scatterplot(
    data=df,
    x="CPI",
    y="Unemployment",
)

plt.show()

# %%
plt.figure(figsize=(6, 4))

sns.lineplot(
    data=df,
    x="CPI",
    y="Unemployment",
)

plt.show()

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
Y = df["Weekly_Sales"]

# %%
X = df.drop("Weekly_Sales", axis = 1 )

# %%
X.head()
# Out:
#    Store       Date  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1 2010-02-05             0        42.31       2.572  211.096358
# 1      1 2010-02-12             1        38.51       2.548  211.242170
# 2      1 2010-02-19             0        39.93       2.514  211.289143
# 3      1 2010-02-26             0        46.63       2.561  211.319643
# 4      1 2010-03-05             0        46.50       2.625  211.350143
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# 4         8.106

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state = 42
)

# %%
X_train
# Out:
#       Store       Date  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 1033      8 2010-09-17             0        75.32       2.582  214.878556
# 915       7 2011-03-11             0        20.70       3.372  192.058484
# 5903     42 2010-11-12             0        61.24       3.130  126.546161
# 2083     15 2011-08-26             0        69.19       3.906  136.213613
# 5943     42 2011-08-19             0        87.40       3.743  129.240581
# ...     ...        ...           ...          ...         ...         ...
# 3772     27 2011-02-18             0        39.32       3.420  137.251185
# 5191     37 2010-12-03             0        54.44       2.708  210.376263
# 5226     37 2011-08-05             0        86.71       3.684  214.297294
# 5390     38 2011-12-30             1        44.64       3.428  130.071032
# 860       7 2010-02-19             0        27.28       2.550  189.534100
#
#       Unemployment
# 1033         6.315
# 915          8.818
# ...

# %%
X_test
# Out:
#       Store       Date  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 2436     18 2010-03-12             0        42.39       2.805  131.784000
# 3361     24 2011-06-24             0        68.88       3.964  135.265267
# 233       2 2011-10-28             0        65.87       3.372  217.325182
# 3667     26 2011-11-11             0        40.08       3.570  136.461806
# 5011     36 2010-03-19             0        59.56       2.701  209.980321
# ...     ...        ...           ...          ...         ...         ...
# 2600     19 2010-08-06             0        74.20       2.942  132.614193
# 6308     45 2010-05-28             0        69.27       2.899  182.046418
# 6292     45 2010-02-05             0        27.31       2.784  181.871190
# 151       2 2010-04-02             0        63.27       2.719  210.479887
# 2344     17 2011-03-04             0        24.21       3.230  128.264750
#
#       Unemployment
# 2436         9.202
# 3361         8.212
# ...

# %%
X = df.drop(columns=["Weekly_Sales", "Date"])
Y = df["Weekly_Sales"]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, Y_train)
# Out:
# Model training completed successfully!

# %%
predictions = model.predict(X_test)

print("First 5 predictions:", predictions[:5])
# Out:
# First 5 predictions: [1196174.80018843 1096306.76027313 1261762.99266103 1102194.4287541
#   746743.23493123]

# %%
from sklearn.metrics import mean_squared_error, r2_score

Y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared Score (R2): {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 274455221280.66
# R-squared Score (R2): 0.1481

# %%
from sklearn.metrics import mean_squared_error, r2_score
Y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared Score (R2): {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 274455221280.66
# R-squared Score (R2): 0.1481

# %%
importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_
})

importance_df['Absolute_Impact'] = importance_df['Coefficient'].abs()
importance_df = importance_df.sort_values(by='Absolute_Impact', ascending=False).drop(columns=['Absolute_Impact'])

print(importance_df.to_string(index=False))
# Out:
#      Feature   Coefficient
# Holiday_Flag  76321.851667
# Unemployment -24502.350593
#        Store -15079.609530
#   Fuel_Price  -4654.770880
#          CPI  -2318.249926
#  Temperature   -761.886905
