# %% [markdown]
# ## Project 9: AI Use-Case Design

# %%
# Design an AI solution

# Select appropriate AI approach

# Identify an AI-solvable business problem

# Identify risks and ethical concerns

# %%
import pandas as pd

# 1. Identify AI-Solvable Business Problem
problem_statement = {
    "Business Domain": "E-Commerce / Subscription Services",
    "Problem": "High customer churn rates leading to revenue loss",
    "Objective": "Identify at-risk customers early and dynamically trigger personalized retention offers",
    "Success Metric": "Reduce churn rate by 15% and increase customer lifetime value (LTV)"
}

# 2. Select Appropriate AI Approach
ai_approach = {
    "Task Type": "Supervised Binary Classification & Recommendation Engine",
    "Primary Algorithm": "XGBoost / Random Forest Classifier",
    "Alternative Approach": "LSTM Networks (for sequential behavioral log data)",
    "Deployment Strategy": "REST API via FastAPI deployed on AWS Lambda for real-time scoring"
}

print("=== 1. BUSINESS PROBLEM ===")
for key, val in problem_statement.items():
    print(f"{key}: {val}")

print("\n=== 2. AI APPROACH ===")
for key, val in ai_approach.items():
    print(f"{key}: {val}")
# Out:
# === 1. BUSINESS PROBLEM ===
# Business Domain: E-Commerce / Subscription Services
# Problem: High customer churn rates leading to revenue loss
# Objective: Identify at-risk customers early and dynamically trigger personalized retention offers
# Success Metric: Reduce churn rate by 15% and increase customer lifetime value (LTV)
#
# === 2. AI APPROACH ===
# Task Type: Supervised Binary Classification & Recommendation Engine
# Primary Algorithm: XGBoost / Random Forest Classifier
# Alternative Approach: LSTM Networks (for sequential behavioral log data)
# Deployment Strategy: REST API via FastAPI deployed on AWS Lambda for real-time scoring

# %%
import pandas as pd

solution_architecture = [
    {"Stage": "1. Ingestion", "Component": "Kafka / Event Hub", "Function": "Real-time stream of user events, transactions, and session logs."},
    {"Stage": "2. Preprocessing", "Component": "Spark / Pandas", "Function": "Feature engineering, scaling, and computing engagement metrics."},
    {"Stage": "3. Inference Engine", "Component": "XGBoost via FastAPI", "Function": "Evaluates risk probability score (0.0 to 1.0) on incoming user payloads."},
    {"Stage": "4. Action Engine", "Component": "CRM Webhook API", "Function": "Triggers personalized retention offers when risk score exceeds 0.70."}
]

solution_df = pd.DataFrame(solution_architecture)
print("=== AI SOLUTION ARCHITECTURE ===")
solution_df
# Out:
# === AI SOLUTION ARCHITECTURE ===
#                  Stage            Component  \
# 0         1. Ingestion    Kafka / Event Hub
# 1     2. Preprocessing       Spark / Pandas
# 2  3. Inference Engine  XGBoost via FastAPI
# 3     4. Action Engine      CRM Webhook API
#
#                                             Function
# 0  Real-time stream of user events, transactions,...
# 1  Feature engineering, scaling, and computing en...
# 2  Evaluates risk probability score (0.0 to 1.0) ...
# 3  Triggers personalized retention offers when ri...

# %%
import pandas as pd

ai_approach_data = {
    "Criteria": [
        "Problem Type",
        "Selected Algorithm",
        "Evaluation Metric",
        "Framework / Tooling",
        "Deployment Pipeline"
    ],
    "Details": [
        "Supervised Binary Classification & Probability Estimation",
        "XGBoost Classifier (chosen for handling mixed feature types & non-linear patterns)",
        "ROC-AUC and Precision-Recall Curve (prioritizing recall for high-value targets)",
        "Scikit-Learn, XGBoost, SHAP (for explainability)",
        "REST API using FastAPI containerized via Docker"
    ]
}

approach_df = pd.DataFrame(ai_approach_data)
print("=== SELECTED AI APPROACH ===")
approach_df
# Out:
# === SELECTED AI APPROACH ===
#               Criteria                                            Details
# 0         Problem Type  Supervised Binary Classification & Probability...
# 1   Selected Algorithm  XGBoost Classifier (chosen for handling mixed ...
# 2    Evaluation Metric  ROC-AUC and Precision-Recall Curve (prioritizi...
# 3  Framework / Tooling   Scikit-Learn, XGBoost, SHAP (for explainability)
# 4  Deployment Pipeline    REST API using FastAPI containerized via Docker

# %% [markdown]
# ## Identifying an AI-solvable business problem

# %%
import pandas as pd

business_problem = {
    "Domain": "E-Commerce / Subscription Services",
    "Core Problem": "High customer churn rates leading to significant annual revenue loss.",
    "Root Cause": "Inability to detect early indicators of customer dissatisfaction before cancellation.",
    "AI Objective": "Predict churn probability in real time based on behavioral logs and trigger targeted retention incentives.",
    "Success KPI": "Reduce quarterly customer churn rate by 15% and increase Customer Lifetime Value (LTV)."
}

problem_df = pd.DataFrame(list(business_problem.items()), columns=["Aspect", "Details"])
print("=== AI-SOLVABLE BUSINESS PROBLEM ===")
problem_df
# Out:
# === AI-SOLVABLE BUSINESS PROBLEM ===
#          Aspect                                            Details
# 0        Domain                 E-Commerce / Subscription Services
# 1  Core Problem  High customer churn rates leading to significa...
# 2    Root Cause  Inability to detect early indicators of custom...
# 3  AI Objective  Predict churn probability in real time based o...
# 4   Success KPI  Reduce quarterly customer churn rate by 15% an...

# %% [markdown]
# ## Identifying risks and ethical concerns

# %%
import pandas as pd

ethical_risks = [
    {
        "Category": "Algorithmic Bias",
        "Risk": "Model may unfairly target or discriminate based on demographic attributes.",
        "Mitigation": "Exclude sensitive personal features and perform regular fairness audits."
    },
    {
        "Category": "Data Privacy",
        "Risk": "Exposure of sensitive customer behavioral data and PII.",
        "Mitigation": "Implement end-to-end encryption, anonymize user IDs, and adhere to GDPR standards."
    },
    {
        "Category": "Model Drift",
        "Risk": "Customer patterns change over time, leading to inaccurate predictions.",
        "Mitigation": "Set up automated performance monitoring and periodic model retraining pipelines."
    },
    {
        "Category": "Explainability",
        "Risk": "Black-box decision making causes lack of trust in automated interventions.",
        "Mitigation": "Use SHAP (SHapley Additive exPlanations) values to explain individual predictions."
    }
]

risk_df = pd.DataFrame(ethical_risks)
print("=== RISKS & ETHICAL CONCERNS ===")
risk_df
# Out:
# === RISKS & ETHICAL CONCERNS ===
#            Category                                               Risk  \
# 0  Algorithmic Bias  Model may unfairly target or discriminate base...
# 1      Data Privacy  Exposure of sensitive customer behavioral data...
# 2       Model Drift  Customer patterns change over time, leading to...
# 3    Explainability  Black-box decision making causes lack of trust...
#
#                                           Mitigation
# 0  Exclude sensitive personal features and perfor...
# 1  Implement end-to-end encryption, anonymize use...
# 2  Set up automated performance monitoring and pe...
# 3  Use SHAP (SHapley Additive exPlanations) value...
