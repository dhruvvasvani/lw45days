# %% [markdown]
# ## Project 10: End-to-End ML Workflow

# %%
#Data Ingestion & Preprocessing Pipeline
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

pipeline_steps = {
    "Step 1: Ingestion": "Fetch batch/stream data from AWS S3 / Feature Store",
    "Step 2: Cleaning": "Handle missing values, remove outliers, and drop redundant features",
    "Step 3: Encoding": "One-Hot Encode categorical variables, map binary targets",
    "Step 4: Scaling": "Apply StandardScaler on numerical inputs to prevent data leakage",
    "Step 5: Splitting": "Perform 80/20 Stratified Train-Test Split"
}

data_pipeline_df = pd.DataFrame(list(pipeline_steps.items()), columns=["Pipeline Stage", "Implementation Strategy"])
print("1. DATA PIPELINE DESIGN")
data_pipeline_df
# Out:
# 1. DATA PIPELINE DESIGN
#       Pipeline Stage                            Implementation Strategy
# 0  Step 1: Ingestion  Fetch batch/stream data from AWS S3 / Feature ...
# 1   Step 2: Cleaning  Handle missing values, remove outliers, and dr...
# 2   Step 3: Encoding  One-Hot Encode categorical variables, map bina...
# 3    Step 4: Scaling  Apply StandardScaler on numerical inputs to pr...
# 4  Step 5: Splitting          Perform 80/20 Stratified Train-Test Split

# %%
#Model Development & Training
from sklearn.ensemble import RandomForestClassifier

model_config = {
    "Algorithm": "RandomForestClassifier",
    "Hyperparameters": "{'n_estimators': 100, 'max_depth': 10, 'random_state': 42}",
    "Training Strategy": "5-Fold Cross-Validation on Training Set",
    "Model Registry": "MLflow tracking for experiment logs and artifacts"
}

model_df = pd.DataFrame(list(model_config.items()), columns=["Configuration", "Details"])
print("2. MODEL TRAINING SETUP")
model_df
# Out:
# 2. MODEL TRAINING SETUP
#        Configuration                                            Details
# 0          Algorithm                             RandomForestClassifier
# 1    Hyperparameters  {'n_estimators': 100, 'max_depth': 10, 'random...
# 2  Training Strategy            5-Fold Cross-Validation on Training Set
# 3     Model Registry  MLflow tracking for experiment logs and artifacts

# %%
#Production Evaluation & Monitoring
eval_metrics = [
    {"Metric": "Accuracy / F1-Score", "Threshold": "> 0.90", "Purpose": "Measure baseline prediction quality"},
    {"Metric": "ROC-AUC", "Threshold": "> 0.85", "Purpose": "Ensure strong class separation"},
    {"Metric": "Data Drift (KS-Test)", "Threshold": "p-value > 0.05", "Purpose": "Detect changes in input data distributions"},
    {"Metric": "Model Drift", "Threshold": "Accuracy drop < 2%", "Purpose": "Trigger automated retraining pipeline"}
]

eval_df = pd.DataFrame(eval_metrics)
print("3. EVALUATION & MONITORING ")
eval_df
# Out:
# 3. EVALUATION & MONITORING
#                  Metric           Threshold  \
# 0   Accuracy / F1-Score              > 0.90
# 1               ROC-AUC              > 0.85
# 2  Data Drift (KS-Test)      p-value > 0.05
# 3           Model Drift  Accuracy drop < 2%
#
#                                       Purpose
# 0         Measure baseline prediction quality
# 1              Ensure strong class separation
# 2  Detect changes in input data distributions
# 3       Trigger automated retraining pipeline

# %%
#Deployment, Ethics & Governance
ethics_governance = [
    {"Area": "API Deployment", "Implementation": "Containerized FastAPI microservice deployed on Kubernetes (EKS)"},
    {"Area": "Fairness & Bias", "Implementation": "Exclude protected attributes; audit parity across subgroups via Fairlearn"},
    {"Area": "Privacy & Security", "Implementation": "Anonymize PII, use TLS encryption, and enforce role-based access controls"},
    {"Area": "Explainability", "Implementation": "Expose SHAP value summary graphs for model auditability and trust"}
]

ethics_df = pd.DataFrame(ethics_governance)
print("4. DEPLOYMENT, ETHICS & GOVERNANCE")
ethics_df
# Out:
# 4. DEPLOYMENT, ETHICS & GOVERNANCE
#                  Area                                     Implementation
# 0      API Deployment  Containerized FastAPI microservice deployed on...
# 1     Fairness & Bias  Exclude protected attributes; audit parity acr...
# 2  Privacy & Security  Anonymize PII, use TLS encryption, and enforce...
# 3      Explainability  Expose SHAP value summary graphs for model aud...

# %%
#Design complete ML workflow
import pandas as pd

workflow_stages = [
    {"Stage": "1. Data Pipeline", "Component": "Feature Store / Pandas", "Details": "Data ingestion, cleaning, feature engineering, and train-test splitting."},
    {"Stage": "2. Model Training", "Component": "Scikit-Learn / MLflow", "Details": "Supervised model fitting, hyperparameter tuning, and experiment logging."},
    {"Stage": "3. Evaluation", "Component": "Metrics & SHAP", "Details": "Validation via Accuracy, F1, ROC-AUC, and SHAP feature explainability."},
    {"Stage": "4. Deployment & Monitoring", "Component": "FastAPI / Evidently AI", "Details": "REST API containerization, automated drift monitoring, and periodic retraining."}
]

workflow_df = pd.DataFrame(workflow_stages)
print("END-TO-END ML WORKFLOW ARCHITECTURE ")
workflow_df
# Out:
# END-TO-END ML WORKFLOW ARCHITECTURE
#                         Stage               Component  \
# 0            1. Data Pipeline  Feature Store / Pandas
# 1           2. Model Training   Scikit-Learn / MLflow
# 2               3. Evaluation          Metrics & SHAP
# 3  4. Deployment & Monitoring  FastAPI / Evidently AI
#
#                                              Details
# 0  Data ingestion, cleaning, feature engineering,...
# 1  Supervised model fitting, hyperparameter tunin...
# 2  Validation via Accuracy, F1, ROC-AUC, and SHAP...
# 3  REST API containerization, automated drift mon...
